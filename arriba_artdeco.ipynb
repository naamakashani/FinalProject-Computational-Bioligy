# %%
import subprocess
import os
import shutil
import re
import pandas as pd
import pyensembl
import math

# %%
def run_bedtools_intersect(bed_file1, bed_file2, output_file): # flags : stranded, c -report the number of hits
    # Run intersectBed on the two inputs file
    command = ['intersectBed', '-a', bed_file1, '-b', bed_file2,'-s', '-c']
    with open(output_file, 'w') as file:
        process = subprocess.Popen(command, stdout=file, stderr=subprocess.PIPE)
        stdout, stderr = process.communicate()

    if process.returncode != 0:
        print(f"Error running 'bettools intersect': {stderr.decode('utf-8')}")
    else:
        print(f"'bedtools intersect' executed successfully. Output saved to {output_file}.")

# %%
#  switch the start and end positions whenever the start position is greater than the end position
def switch_start_end(input_bed, output_bed):
    with open(input_bed, 'r') as input_file, open(output_bed, 'w') as output_file:
        for line in input_file:
            fields = line.strip().split('\t')
            if int(fields[1]) > int(fields[2]):
                # Swap start and end positions
                fields[1], fields[2] = fields[2], fields[1]
            output_file.write('\t'.join(fields) + '\n')

# %%
# not need to run every time!!!
#  switch the start and end positions whenever the start position is greater than the end position
input_bed = "/private/projects/kidney_rtt/bed_arriba_output/TCGA-CZ-5465-11A-01R-1503-07.filterd.more.bed"
output_bed = "/private/projects/kidney_rtt/bed_arriba_output/TCGA-CZ-5465-11A-01R-1503-07.filterd.more.switchStartEnd.bed"
switch_start_end(input_bed, output_bed)

# %%
artdeco_bed = "/home/ls/parshas/5465_results/all_dogs_withnames.bed"
arriba_bed = "/private/projects/kidney_rtt/bed_arriba_output/TCGA-CZ-5465-11A-01R-1503-07.filterd.more.switchStartEnd.bed"
output = "/home/ls/parshas/vscode/5465_processing/5465_intersect_artdeco_arriba.txt"

run_bedtools_intersect(artdeco_bed, arriba_bed, output)
# Out:
# 'bedtools intersect' executed successfully. Output saved to /home/ls/parshas/vscode/5464_processing/5465_intersect_artdeco_arriba.txt.

# %%
def count_lines_with_zero_last_column(file_path):
    total_lines = 0
    zero_lines = 0

    with open(file_path, 'r') as file:
        for line in file:
            fields = line.strip().split('\t')
            total_lines += 1
            if fields[-1] == '0':
                zero_lines += 1

    percentage = (zero_lines / total_lines) * 100

    return zero_lines, percentage

# %%
zero_count, zero_percentage = count_lines_with_zero_last_column('/home/ls/parshas/vscode/5465_processing/5465_intersect_artdeco_arriba.txt')
print("Number of lines with 0 in the last column:", zero_count)
print("Percentage of lines with 0 in the last column: {:.2f}%".format(zero_percentage))
# Out:
# Number of lines with 0 in the last column: 823
# Percentage of lines with 0 in the last column: 43.22%

# %%
# basic filter arriba

# not need to run every time!!!
#  switch the start and end positions whenever the start position is greater than the end position
input_bed = "/private/projects/kidney_rtt/bed_arriba_output_basic_filter/TCGA-CZ-5465-11A-01R-1503-07.bed"
output_bed = "/private/projects/kidney_rtt/bed_arriba_output_basic_filter/TCGA-CZ-5465-11A-01R-1503-07_switchStartEnd.bed"
switch_start_end(input_bed, output_bed)

# %%
artdeco_bed = "/home/ls/parshas/5465_results/all_dogs_withnames.bed"
arriba_bed = "/private/projects/kidney_rtt/bed_arriba_output_basic_filter/TCGA-CZ-5465-11A-01R-1503-07_switchStartEnd.bed"
output = "/home/ls/parshas/vscode/5465_processing/5465_intersect_artdeco_arriba_basic_filter.txt"

run_bedtools_intersect(artdeco_bed, arriba_bed, output)
# Out:
# 'bedtools intersect' executed successfully. Output saved to /home/ls/parshas/vscode/5464_processing/5465_intersect_artdeco_arriba_basic_filter.txt.

# %%
zero_count, zero_percentage = count_lines_with_zero_last_column('/home/ls/parshas/vscode/5465_processing/5465_intersect_artdeco_arriba_basic_filter.txt')
print("Number of lines with 0 in the last column:", zero_count)
print("Percentage of lines with 0 in the last column: {:.2f}%".format(zero_percentage))
# Out:
# Number of lines with 0 in the last column: 797
# Percentage of lines with 0 in the last column: 41.86%

# %%
# for no_filter
input_bed = "/private/projects/kidney_rtt/no_filter_arriba_bed/TCGA-CZ-5465-11A-01R-1503-07.bed"
output_bed = "/private/projects/kidney_rtt/no_filter_arriba_bed/TCGA-CZ-5465-11A-01R-1503-07_switchStartEnd.bed"
switch_start_end(input_bed, output_bed)
artdeco_bed = "/home/ls/parshas/5465_results/all_dogs_withnames.bed"
arriba_bed = "/private/projects/kidney_rtt/no_filter_arriba_bed/TCGA-CZ-5465-11A-01R-1503-07_switchStartEnd.bed"
output = "/home/ls/parshas/vscode/5465_processing/5465_intersect_artdeco_arriba_no_filter.txt"
run_bedtools_intersect(artdeco_bed, arriba_bed, output)
zero_count, zero_percentage = count_lines_with_zero_last_column('/home/ls/parshas/vscode/5465_processing/5465_intersect_artdeco_arriba_no_filter.txt')
print("Number of lines with 0 in the last column:", zero_count)
print("Percentage of lines with 0 in the last column: {:.2f}%".format(zero_percentage))
# Out:
# 'bedtools intersect' executed successfully. Output saved to /home/ls/parshas/vscode/5464_processing/5465_intersect_artdeco_arriba_no_filter.txt.
# Number of lines with 0 in the last column: 0
# Percentage of lines with 0 in the last column: 0.00%

# %%
# for intersect elife arriba
elife_bed = "/home/ls/parshas/vscode/5465_processing/elife4565_hg38.bed"
arriba_bed = "/private/projects/kidney_rtt/bed_arriba_output_basic_filter/TCGA-CZ-5465-11A-01R-1503-07_switchStartEnd.bed"
output = "/home/ls/parshas/vscode/5465_processing/5465_intersect_elife_arriba.txt"
run_bedtools_intersect(elife_bed, arriba_bed, output)
zero_count, zero_percentage = count_lines_with_zero_last_column('/home/ls/parshas/vscode/5465_processing/5465_intersect_elife_arriba.txt')
print("Number of lines with 0 in the last column:", zero_count)
print("Percentage of lines with 0 in the last column: {:.2f}%".format(zero_percentage))
# Out:
# 'bedtools intersect' executed successfully. Output saved to /home/ls/parshas/vscode/5464_processing/5465_intersect_elife_arriba.txt.
# Number of lines with 0 in the last column: 277
# Percentage of lines with 0 in the last column: 46.24%

# %%
# for intersect elife artdeco
elife_bed = "/home/ls/parshas/vscode/5465_processing/elife4565_hg38.bed"
artdeco_bed = "/home/ls/parshas/5465_results/all_dogs_withnames.bed"
output = "/home/ls/parshas/vscode/5465_processing/5465_intersect_elife_artdeco.txt"
run_bedtools_intersect(elife_bed, artdeco_bed, output)
zero_count, zero_percentage = count_lines_with_zero_last_column('/home/ls/parshas/vscode/5465_processing/5465_intersect_elife_artdeco.txt')
print("Number of lines with 0 in the last column:", zero_count)
print("Percentage of lines with 0 in the last column: {:.2f}%".format(zero_percentage))
# Out:
# 'bedtools intersect' executed successfully. Output saved to /home/ls/parshas/vscode/5464_processing/5465_intersect_elife_artdeco.txt.
# Number of lines with 0 in the last column: 599
# Percentage of lines with 0 in the last column: 100.00%

# %%
# for basic2_filter
# filters - /private/projects/kidney_rtt/all_plots/python_arriba/basic2_filters.txt
input_bed = "/private/projects/kidney_rtt/bed_arriba_output_basic2_filter/TCGA-CZ-5465-11A-01R-1503-07.bed"
output_bed = "/private/projects/kidney_rtt/bed_arriba_output_basic2_filter/TCGA-CZ-5465-11A-01R-1503-07_switchStartEnd.bed"
switch_start_end(input_bed, output_bed)
artdeco_bed = "/home/ls/parshas/5465_results/all_dogs_withnames.bed"
arriba_bed = "/private/projects/kidney_rtt/bed_arriba_output_basic2_filter/TCGA-CZ-5465-11A-01R-1503-07_switchStartEnd.bed"
output = "/home/ls/parshas/vscode/5465_processing/5465_intersect_artdeco_arriba_basic2_filter.txt"
run_bedtools_intersect(artdeco_bed, arriba_bed, output)
zero_count, zero_percentage = count_lines_with_zero_last_column('/home/ls/parshas/vscode/5465_processing/5465_intersect_artdeco_arriba_basic2_filter.txt')
print("Number of lines with 0 in the last column:", zero_count)
print("Percentage of lines with 0 in the last column: {:.2f}%".format(zero_percentage))
# Out:
# 'bedtools intersect' executed successfully. Output saved to /home/ls/parshas/vscode/5464_processing/5465_intersect_artdeco_arriba_basic2_filter.txt.
# Number of lines with 0 in the last column: 390
# Percentage of lines with 0 in the last column: 20.48%

# %%
# for marge_dup_filter
artdeco_bed = "/home/ls/parshas/5465_results/all_dogs_withnames.bed"
arriba_bed = "/private/projects/kidney_rtt/merge_gene1_bed/new2.bed"
output = "/home/ls/parshas/vscode/5465_processing/5465_intersect_artdeco_arriba_merge_filter.txt"
run_bedtools_intersect(artdeco_bed, arriba_bed, output)
zero_count, zero_percentage = count_lines_with_zero_last_column(output)
print("Number of lines with 0 in the last column:", zero_count)
print("Percentage of lines with 0 in the last column: {:.2f}%".format(zero_percentage))
print("Percentage of lines without 0 in the last column:\t{:.2f}%\n\n".format(100 - zero_percentage))
# Out:
# 'bedtools intersect' executed successfully. Output saved to /home/ls/parshas/vscode/5465_processing/5465_intersect_artdeco_arriba_merge_filter.txt.
# Number of lines with 0 in the last column: 411
# Percentage of lines with 0 in the last column: 21.59%
# Percentage of lines without 0 in the last column:	78.41%

# %%
# for marge_dup_filter - intersect arriba vs artdeco (no artdeco vs arriba!)
artdeco_bed = "/home/ls/parshas/5465_results/all_dogs_withnames.bed"
arriba_bed = "/private/projects/kidney_rtt/merge_gene1_bed/new2.bed"
output = "/home/ls/parshas/vscode/5465_processing/5465_intersect_arriba_merge_vs_artdeco__filter.txt"
run_bedtools_intersect(arriba_bed, artdeco_bed , output)
zero_count, zero_percentage = count_lines_with_zero_last_column(output)
print("Number of lines with 0 in the last column:", zero_count)
print("Percentage of lines with 0 in the last column: {:.2f}%".format(zero_percentage))
print("Percentage of lines without 0 in the last column:\t{:.2f}%\n\n".format(100 - zero_percentage))
# Out:
# 'bedtools intersect' executed successfully. Output saved to /home/ls/parshas/vscode/5465_processing/5465_intersect_arriba_merge_vs_artdeco__filter.txt.
# Number of lines with 0 in the last column: 18610
# Percentage of lines with 0 in the last column: 87.46%
# Percentage of lines without 0 in the last column:	12.54%

# %%
# for marge_dup__add_indo - intersect arriba vs artdeco (no artdeco vs arriba!)
artdeco_bed = "/home/ls/parshas/5465_results/all_dogs_withnames.bed"
arriba_bed = "/private/projects/kidney_rtt/merge_gene1_bed/new3.bed"
output = "/home/ls/parshas/vscode/5465_processing/5465_intersect_arriba_merge_vs_artdeco_add_info.txt"
run_bedtools_intersect(arriba_bed, artdeco_bed , output)
zero_count, zero_percentage = count_lines_with_zero_last_column(output)
print("Number of lines with 0 in the last column:", zero_count)
print("Percentage of lines with 0 in the last column: {:.2f}%".format(zero_percentage))
print("Percentage of lines without 0 in the last column:\t{:.2f}%\n\n".format(100 - zero_percentage))
# Out:
# 'bedtools intersect' executed successfully. Output saved to /home/ls/parshas/vscode/5465_processing/5465_intersect_arriba_merge_vs_artdeco_add_info.txt.
# Number of lines with 0 in the last column: 18610
# Percentage of lines with 0 in the last column: 87.46%
# Percentage of lines without 0 in the last column:	12.54%

# %%
# for filter_3
# filters:
# Arriba filtering - try to find fusions from readthrough
# We filter out fusions from different chromosomes. 
# We filtered if fusion type contains translocation or inversions
# We calculated the distance between the breakpoints and filtered out distances that grader than 0.5kb. 
# We filtered fusions that came from mitochondrial chromosome. 
# We filtered fusion that exist in star-fusion on gtex. 
# We filtered out fusions that came from the same gene and site1 and site 2 are integenic.
# We filter out if site1 or site 2 is intron. 
# We filtered out if the filters contains ‘blacklist’

input_bed = "/private/projects/kidney_rtt/new/TCGA-CZ-5465-11A-01R-1503-07.bed"
output_bed = "/private/projects/kidney_rtt/new/TCGA-CZ-5465-11A-01R-1503-07_switchStartEnd.bed"
switch_start_end(input_bed, output_bed)
artdeco_bed = "/home/ls/parshas/5465_results/all_dogs_withnames.bed"
arriba_bed = "/private/projects/kidney_rtt/new/TCGA-CZ-5465-11A-01R-1503-07_switchStartEnd.bed"
output = "/home/ls/parshas/vscode/5465_processing/5465_intersect_artdeco_arriba_filter_3.txt"
run_bedtools_intersect(artdeco_bed, arriba_bed, output)
zero_count, zero_percentage = count_lines_with_zero_last_column('/home/ls/parshas/vscode/5465_processing/5465_intersect_artdeco_arriba_filter_3.txt')
print("Number of lines with 0 in the last column:", zero_count)
print("Percentage of lines with 0 in the last column: {:.2f}%".format(zero_percentage))
# Out:
# 'bedtools intersect' executed successfully. Output saved to /home/ls/parshas/vscode/5464_processing/5465_intersect_artdeco_arriba_filter_3.txt.
# Number of lines with 0 in the last column: 368
# Percentage of lines with 0 in the last column: 19.33%

# %%
# move all the dogs files to new directory

# Function to loop over files in directory and subdirectories
def loop_files(directory, new_directory):
    # Loop over files in directory and subdirectories
    for root, _, files in os.walk(directory):
        for filename in files:
            print(filename)
            if filename.endswith(".dogs.bed"):
                file_path = os.path.join(root, filename)
                new_file_path = os.path.join(new_directory, filename)
                print(file_path)
                print(new_file_path)
                # Copy the file to the new directory
                shutil.copy(file_path, new_file_path)


loop_files("/private/projects/kidney_rtt/tcga_output", "/private/projects/kidney_rtt/dogs_all_samples")
loop_files("/private/projects/kidney_rtt/artdeco_run", "/private/projects/kidney_rtt/dogs_all_samples")

# %%
# Function to find files containing a specific number in their names
def find_files_with_number(directory, number):
    # Compile the regular expression pattern to match the number in the filename
    pattern = re.compile(fr".*{number}.*", re.IGNORECASE)

    # List to store the matching filenames
    matching_files = []

    # Loop over files in the directory
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)

        # Check if the filename matches the pattern
        if pattern.match(filename):
            matching_files.append(file_path)

    return matching_files

# %%
# apply the intersect with dogs and count_lines_with_zero_last_column on all the bed file from the output of arriba

# Specify the directory path
directory_arriba = '/private/projects/kidney_rtt/filters_arriba_bed'
directory_artdeco = "/private/projects/kidney_rtt/dogs_all_samples"
samples_not_found_in_arriba = []
# Loop over files in the directory
for filename in os.listdir(directory_artdeco):
    if filename.endswith(".bed"):  
        file_path_artdeco = os.path.join(directory_artdeco, filename)
        artdeco_bed = file_path_artdeco
        split_list = filename.split("-")
        number_sample = split_list[2]
        print("number sample : ", number_sample)
        
        arriba_bed_files = find_files_with_number(directory_arriba, number_sample)
        print(arriba_bed_files)
        if(len(arriba_bed_files)==0):
            samples_not_found_in_arriba.append(number_sample)
            continue
        arriba_bed = arriba_bed_files[0]

        new_filename = f"intersect_{filename}"
        output_path = os.path.join("/private/projects/kidney_rtt/intersect_all_samples", new_filename)

        run_bedtools_intersect(artdeco_bed, arriba_bed, output_path)
        zero_count, zero_percentage = count_lines_with_zero_last_column(output_path)

        summary_path = "/private/projects/kidney_rtt/intersect_all_samples/summary_intersect.txt"
        with open(summary_path, 'a') as sammary:
            sammary.write("sample: "+str(number_sample)+"\n")
            sammary.write("Number of lines with 0 in the last column:\t" + str(zero_count) + "\n")
            sammary.write("Percentage of lines with 0 in the last column:\t{:.2f}%\n".format(zero_percentage))
            sammary.write("Percentage of lines without 0 in the last column:\t{:.2f}%\n\n".format(100 - zero_percentage))
print("samples not found in arriba: ", samples_not_found_in_arriba)
# Out:
# number sample :  A8L7
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-G6-A8L7-01A-11R-A37O-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-G6-A8L7-01A-11R-A37O-07.dogs.bed.
# number sample :  3778
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AS-3778-01A-01R-A32Z-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AS-3778-01A-01R-A32Z-07.dogs.bed.
# number sample :  A8OX
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-A8OX-01A-11R-A37O-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-A8OX-01A-11R-A37O-07.dogs.bed.
# number sample :  3372
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3372-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3372-01A-02R-1325-07.dogs.bed.
# number sample :  3326
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3326-01A-01R-0864-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3326-01A-01R-0864-07.dogs.bed.
# number sample :  3320
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3320-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3320-01A-02R-1325-07.dogs.bed.
# number sample :  3323
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3323-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3323-01A-02R-1325-07.dogs.bed.
# number sample :  3387
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3387-01A-01R-1541-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3387-11A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3387-11A-01R-1541-07.dogs.bed.
# number sample :  3322
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3322-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3322-01A-02R-1325-07.dogs.bed.
# number sample :  3434
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3434-01A-02R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3434-01A-02R-1277-07.dogs.bed.
# number sample :  3429
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3429-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3429-01A-02R-1325-07.dogs.bed.
# number sample :  3451
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3451-01A-02R-1188-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3451-01A-02R-1188-07.dogs.bed.
# number sample :  3440
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3440-01A-02R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3440-01A-02R-1277-07.dogs.bed.
# number sample :  5812
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5812-01A-11R-1672-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5812-01A-11R-1672-07.dogs.bed.
# number sample :  4712
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4712-01A-01R-1503-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4712-11A-02R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4712-01A-01R-1503-07.dogs.bed.
# number sample :  4703
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4703-01A-01R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4703-01A-01R-1277-07.dogs.bed.
# number sample :  5400
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5400-01A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5400-01A-01R-1503-07.dogs.bed.
# number sample :  5709
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5709-11A-01R-1541-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5709-01A-11R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5709-11A-01R-1541-07.dogs.bed.
# number sample :  5700
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5700-01A-11R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5700-01A-11R-1541-07.dogs.bed.
# number sample :  4823
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4823-01A-02R-1420-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4823-01A-02R-1420-07.dogs.bed.
# number sample :  4833
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4833-01A-01R-1305-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4833-01A-01R-1305-07.dogs.bed.
# number sample :  5399
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5399-01A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5399-01A-01R-1503-07.dogs.bed.
# number sample :  4842
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4842-01A-02R-1420-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4842-01A-02R-1420-07.dogs.bed.
# number sample :  5697
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5697-11A-01R-1541-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5697-01A-11R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5697-11A-01R-1541-07.dogs.bed.
# number sample :  4814
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4814-01A-01R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4814-01A-01R-1277-07.dogs.bed.
# number sample :  4810
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4810-01A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4810-01A-01R-1503-07.dogs.bed.
# number sample :  5695
# []
# number sample :  4337
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4337-01A-01R-1289-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4337-01A-01R-1289-07.dogs.bed.
# number sample :  4164
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4164-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4164-01A-02R-1325-07.dogs.bed.
# number sample :  5168
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-5168-01A-01R-1420-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-5168-01A-01R-1420-07.dogs.bed.
# number sample :  4807
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4807.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4807-01A-01R-1305-07.dogs.bed.
# number sample :  4804
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4804-01A-02R-1305-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4804-01A-02R-1305-07.dogs.bed.
# number sample :  4771
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4771-01A-01R-1289-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4771-01A-01R-1289-07.dogs.bed.
# number sample :  4327
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4327-01A-01R-1289-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4327-01A-01R-1289-07.dogs.bed.
# number sample :  5175
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-5175-01A-01R-1426-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-5175-01A-01R-1426-07.dogs.bed.
# number sample :  4329
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4329-01A-02R-1289-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4329-01A-02R-1289-07.dogs.bed.
# number sample :  4173
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4173-01A-02R-1289-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4173-01A-02R-1289-07.dogs.bed.
# number sample :  4344
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4344-01A-01R-1289-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4344-01A-01R-1289-07.dogs.bed.
# number sample :  4177
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4177-01A-02R-1420-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4177-01A-02R-1420-07.dogs.bed.
# number sample :  4334
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4334-01A-01R-1289-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4334-01A-01R-1289-07.dogs.bed.
# number sample :  4170
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4170-01A-02R-1289-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4170-01A-02R-1289-07.dogs.bed.
# number sample :  4341
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4341-01A-01R-1289-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4341-01A-01R-1289-07.dogs.bed.
# number sample :  4332
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4332-01A-01R-1289-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4332-01A-01R-1289-07.dogs.bed.
# number sample :  5181
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-5181-01A-01R-1426-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-5181-01A-01R-1426-07.dogs.bed.
# number sample :  4765
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4765-01A-01R-1289-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4765-01A-01R-1289-07.dogs.bed.
# number sample :  A54D
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B8-A54D-01A-21R-A266-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B8-A54D-01A-21R-A266-07.dogs.bed.
# number sample :  5552
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B8-5552-01B-11R-1672-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B8-5552-11A-01R-1672-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B8-5552-11A-01R-1672-07.dogs.bed.
# number sample :  4102
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B2-4102-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B2-4102-01A-02R-1325-07.dogs.bed.
# number sample :  5832
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B4-5832-01A-11R-1672-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B4-5832-01A-11R-1672-07.dogs.bed.
# number sample :  4620
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B8-4620-01A-02R-1325-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B8-4620-11A-01R-1758-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B8-4620-01A-02R-1325-07.dogs.bed.
# number sample :  5546
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B8-5546-01A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B8-5546-01A-01R-1541-07.dogs.bed.
# number sample :  4098
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B2-4098-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B2-4098-01A-02R-1325-07.dogs.bed.
# number sample :  A4W0
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-DV-A4W0-01A-11R-A266-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-DV-A4W0-05A-11R-A266-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-DV-A4W0-05A-11R-A266-07.dogs.bed.
# number sample :  5987
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CZ-5987-01A-11R-1672-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CZ-5987-11A-01R-1672-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CZ-5987-01A-11R-1672-07.dogs.bed.
# number sample :  4894
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CJ-4894-01A-01R-1305-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CJ-4894-01A-01R-1305-07.dogs.bed.
# number sample :  5986
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CZ-5986-01A-11R-1672-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CZ-5986-11A-01R-1672-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CZ-5986-11A-01R-1672-07.dogs.bed.
# number sample :  5576
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-DV-5576-01A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-DV-5576-01A-01R-1541-07.dogs.bed.
# number sample :  5985
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CZ-5985-11A-01R-1672-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CZ-5985-11A-01R-1672-07.dogs.bed.
# number sample :  5675
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CJ-5675-01A-11R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CJ-5675-01A-11R-1541-07.dogs.bed.
# number sample :  A563
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-MM-A563-01A-11R-A266-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-MM-A563-01A-11R-A266-07.dogs.bed.
# number sample :  4644
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CJ-4644-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CJ-4644-01A-02R-1325-07.dogs.bed.
# number sample :  5588
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CW-5588-01A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CW-5588-01A-01R-1541-07.dogs.bed.
# number sample :  5584
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CW-5584-01A-01R-1541-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CW-5584-11A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CW-5584-01A-01R-1541-07.dogs.bed.
# number sample :  5988
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CZ-5988-01A-11R-1672-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CZ-5988-11A-01R-1672-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CZ-5988-01A-11R-1672-07.dogs.bed.
# number sample :  5904
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-EU-5904-01A-11R-1672-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-EU-5904-01A-11R-1672-07.dogs.bed.
# number sample :  6033
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CJ-6033-01A-11R-1672-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CJ-6033-11A-01R-1858-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CJ-6033-01A-11R-1672-07.dogs.bed.
# number sample :  4869
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CJ-4869-01A-02R-1426-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CJ-4869-01A-02R-1426-07.dogs.bed.
# number sample :  4908
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CJ-4908-01A-01R-1426-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CJ-4908-01A-01R-1426-07.dogs.bed.
# number sample :  5465
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CZ-5465-11A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CZ-5465-11A-01R-1503-07.downsample.dogs.bed.
# number sample :  3380
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3380-01A-01R-0864-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3380-01A-01R-0864-07.downsample.dogs.bed.
# number sample :  5088
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5088-01A-01R-1334-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5088-01A-01R-1334-07.downsample.dogs.bed.
# number sample :  4621
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B8-4621-01A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B8-4621-01A-01R-1503-07.downsample.dogs.bed.
# number sample :  5104
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5104-01A-01R-1420-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5104-01A-01R-1420-07.downsample.dogs.bed.
# number sample :  3370
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3370-01A-02R-1420-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3370-01A-02R-1420-07.downsample.dogs.bed.
# number sample :  5084
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5084-01A-01R-1334-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5084-01A-01R-1334-07.downsample.dogs.bed.
# number sample :  4972
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4972-01A-01R-1334-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4972-01A-01R-1334-07.downsample.dogs.bed.
# number sample :  5201
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-5201-01A-01R-1426-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-5201-01A-01R-1426-07.downsample.dogs.bed.
# number sample :  4970
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4970-01A-01R-1334-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4970-01A-01R-1334-07.downsample.dogs.bed.
# number sample :  4964
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4964-01A-01R-1334-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4964-01A-01R-1334-07.downsample.dogs.bed.
# number sample :  4965
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4965-01A-01R-1334-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4965-01A-01R-1334-07.downsample.dogs.bed.
# number sample :  4983
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4983-01A-01R-1334-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4983-01A-01R-1334-07.downsample.dogs.bed.
# number sample :  4971
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4971-01A-01R-1334-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4971-01A-01R-1334-07.downsample.dogs.bed.
# number sample :  4960
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-BP-4960-01A-01R-1334-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-BP-4960-01A-01R-1334-07.downsample.dogs.bed.
# number sample :  4918
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CJ-4918-01A-01R-1426-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CJ-4918-01A-01R-1426-07.downsample.dogs.bed.
# number sample :  4916
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CJ-4916-01A-01R-1426-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CJ-4916-01A-01R-1426-07.downsample.dogs.bed.
# number sample :  5678
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CJ-5678-11A-01R-1541-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CJ-5678-01A-11R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CJ-5678-11A-01R-1541-07.downsample.dogs.bed.
# number sample :  4899
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CJ-4899-01A-01R-1334-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CJ-4899-01A-01R-1334-07.downsample.dogs.bed.
# number sample :  4902
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CJ-4902-01A-01R-1426-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CJ-4902-01A-01R-1426-07.downsample.dogs.bed.
# number sample :  4903
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CJ-4903-01A-01R-1426-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CJ-4903-01A-01R-1426-07.downsample.dogs.bed.
# number sample :  4897
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CJ-4897-01A-03R-1426-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CJ-4897-01A-03R-1426-07.downsample.dogs.bed.
# number sample :  5984
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CZ-5984-01A-11R-1672-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CZ-5984-01A-11R-1672-07.downsample.dogs.bed.
# number sample :  5466
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CZ-5466-11A-01R-1503-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CZ-5466-01A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CZ-5466-11A-01R-1503-07.downsample.dogs.bed.
# number sample :  4854
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CZ-4854-01A-01R-1305-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CZ-4854-01A-01R-1305-07.downsample.dogs.bed.
# number sample :  4853
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CZ-4853-01A-01R-1426-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CZ-4853-01A-01R-1426-07.downsample.dogs.bed.
# number sample :  5454
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CZ-5454-01A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CZ-5454-01A-01R-1503-07.downsample.dogs.bed.
# number sample :  4859
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CZ-4859-01A-02R-1426-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CZ-4859-01A-02R-1426-07.downsample.dogs.bed.
# number sample :  4864
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CZ-4864-11A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-CZ-4864-11A-01R-1503-07.downsample.dogs.bed.
# number sample :  A4VZ
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-DV-A4VZ-01A-11R-A266-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-DV-A4VZ-01A-11R-A266-07.dogs.bed.
# number sample :  5566
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-DV-5566-01A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-DV-5566-01A-01R-1541-07.dogs.bed.
# number sample :  5567
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-DV-5567-01A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-DV-5567-01A-01R-1541-07.dogs.bed.
# number sample :  A4W0
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-DV-A4W0-01A-11R-A266-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-DV-A4W0-05A-11R-A266-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-DV-A4W0-01A-11R-A266-07.dogs.bed.
# number sample :  5565
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-DV-5565-01A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-DV-5565-01A-01R-1541-07.dogs.bed.
# number sample :  A4VX
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-DV-A4VX-01A-11R-A266-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-DV-A4VX-01A-11R-A266-07.dogs.bed.
# number sample :  5574
# []
# number sample :  5569
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-DV-5569-01A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-DV-5569-01A-01R-1541-07.dogs.bed.
# number sample :  5568
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-DV-5568-01A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-DV-5568-01A-01R-1541-07.dogs.bed.
# number sample :  5575
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-DV-5575-01A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-DV-5575-01A-01R-1541-07.dogs.bed.
# number sample :  5573
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-DV-5573-01A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-DV-5573-01A-01R-1541-07.dogs.bed.
# number sample :  A84U
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-MM-A84U-01A-11R-A37O-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-MM-A84U-01A-11R-A37O-07.dogs.bed.
# number sample :  5905
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-EU-5905-01A-11R-1672-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-EU-5905-01A-11R-1672-07.dogs.bed.
# number sample :  5907
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-EU-5907.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-EU-5907-01A-11R-1672-07.dogs.bed.
# number sample :  5906
# []
# number sample :  A564
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-MM-A564-01A-11R-A266-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-MM-A564-01A-11R-A266-07.dogs.bed.
# number sample :  A8L8
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-G6-A8L8-01A-21R-A37O-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-G6-A8L8-01A-21R-A37O-07.dogs.bed.
# number sample :  A92I
# []
# number sample :  A6C7
# []
# number sample :  A5PC
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-G6-A5PC-01A-11R-A33J-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-G6-A5PC-01A-11R-A33J-07.dogs.bed.
# number sample :  A4EC
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-MW-A4EC-01A-11R-A266-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-MW-A4EC-01A-11R-A266-07.dogs.bed.
# number sample :  A8L6
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-G6-A8L6-01A-11R-A37O-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-G6-A8L6-01A-11R-A37O-07.dogs.bed.
# number sample :  3325
# []
# number sample :  3385
# []
# number sample :  3328
# []
# number sample :  3376
# []
# number sample :  3363
# []
# number sample :  3352
# []
# number sample :  3346
# []
# number sample :  3367
# []
# number sample :  3357
# []
# number sample :  3313
# []
# number sample :  3373
# []
# number sample :  3335
# []
# number sample :  3358
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3358-11A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3358-01A-01R-1541-07_downsampled.dogs.bed.
# number sample :  3319
# []
# number sample :  3425
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3425-01A-02R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3425-01A-02R-1277-07.dogs.bed.
# number sample :  3426
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3426-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3426-01A-02R-1325-07.dogs.bed.
# number sample :  3428
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3428-01A-02R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3428-01A-02R-1277-07.dogs.bed.
# number sample :  3431
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3431-01A-02R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3431-01A-02R-1277-07.dogs.bed.
# number sample :  3433
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3433-01A-02R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3433-01A-02R-1277-07.dogs.bed.
# number sample :  3436
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3436-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3436-01A-02R-1325-07.dogs.bed.
# number sample :  3445
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3445-01A-02R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3445-01A-02R-1277-07.dogs.bed.
# number sample :  3447
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3447-01A-01R-1766-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3447-01A-01R-1766-07.dogs.bed.
# number sample :  3450
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3450-01A-02R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3450-01A-02R-1277-07.dogs.bed.
# number sample :  3453
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3453-01A-02R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3453-01A-02R-1277-07.dogs.bed.
# number sample :  3454
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3454-01A-02R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3454-01A-02R-1277-07.dogs.bed.
# number sample :  3455
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3455-01A-01R-0864-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3455-01A-01R-0864-07.dogs.bed.
# number sample :  3456
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3456-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3456-01A-02R-1325-07.dogs.bed.
# number sample :  3458
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3458-01A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3458-01A-01R-1503-07.dogs.bed.
# number sample :  3460
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3460-01A-02R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3460-01A-02R-1277-07.dogs.bed.
# number sample :  3461
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3461-01A-02R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3461-01A-02R-1277-07.dogs.bed.
# number sample :  3923
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B2-3923-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B2-3923-01A-02R-1325-07.dogs.bed.
# number sample :  3924
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B2-3924-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B2-3924-01A-02R-1325-07.dogs.bed.
# number sample :  4099
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B2-4099-01A-02R-1188-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B2-4099-01A-02R-1188-07.dogs.bed.
# number sample :  4101
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B2-4101-01A-02R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B2-4101-01A-02R-1277-07.dogs.bed.
# number sample :  5633
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B2-5633-01A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B2-5633-01A-01R-1541-07.dogs.bed.
# number sample :  5635
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B2-5635-01A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B2-5635-01A-01R-1541-07.dogs.bed.
# number sample :  5636
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B2-5636-01A-02R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B2-5636-01A-02R-1541-07.dogs.bed.
# number sample :  5639
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B2-5639-01A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B2-5639-01A-01R-1541-07.dogs.bed.
# number sample :  5641
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B2-5641-01A-01R-1541-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B2-5641-11A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B2-5641-01A-01R-1541-07.dogs.bed.
# number sample :  5641
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B2-5641-01A-01R-1541-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B2-5641-11A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B2-5641-11A-01R-1541-07.dogs.bed.
# number sample :  A4SR
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B2-A4SR-01A-11R-A266-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B2-A4SR-01A-11R-A266-07.dogs.bed.
# number sample :  A6NN
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-A6NN-01A-12R-A33J-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-A6NN-01A-12R-A33J-07.dogs.bed.
# number sample :  A7U6
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B8-A7U6-01A-12R-A37O-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B8-A7U6-01A-12R-A37O-07.dogs.bed.
# number sample :  AA2E
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-6D-AA2E-01A-11R-A37O-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-6D-AA2E-01A-11R-A37O-07.dogs.bed.
# number sample :  3308
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3308-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3308-01A-02R-1325-07.dogs.bed.
# number sample :  3317
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3317-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3317-01A-02R-1325-07.dogs.bed.
# number sample :  3329
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3329-01A-01R-0864-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3329-01A-01R-0864-07.dogs.bed.
# number sample :  3347
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3347-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3347-01A-02R-1325-07.dogs.bed.
# number sample :  3351
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3351-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3351-01A-02R-1325-07.dogs.bed.
# number sample :  3362
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3362-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3362-01A-02R-1325-07.dogs.bed.
# number sample :  3378
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3378-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3378-01A-02R-1325-07.dogs.bed.
# number sample :  A6NI
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-A6NI-01A-11R-A33J-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-A6NI-01A-11R-A33J-07.dogs.bed.
# number sample :  3387
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3387-01A-01R-1541-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3387-11A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3387-01A-01R-1541-07.dogs.bed.
# number sample :  A6NJ
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-A6NJ-01A-12R-A33J-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-A6NJ-01A-12R-A33J-07.dogs.bed.
# number sample :  A8OW
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-A8OW-01A-11R-A37O-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-A8OW-01A-11R-A37O-07.dogs.bed.
# number sample :  A8YJ
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B8-A8YJ-01A-13R-A39I-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B8-A8YJ-01A-13R-A39I-07.dogs.bed.
# number sample :  A93Z
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-3Z-A93Z-01A-11R-A37O-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-3Z-A93Z-01A-11R-A37O-07.dogs.bed.
# number sample :  3307
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3307.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3307-01A-01R-0864-07.dogs.bed.
# number sample :  3316
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3316-01A-01R-0864-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3316-01A-01R-0864-07.dogs.bed.
# number sample :  3324
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3324-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3324-01A-02R-1325-07.dogs.bed.
# number sample :  3343
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3343-01A-01R-0864-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3343-01A-01R-0864-07.dogs.bed.
# number sample :  3349
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3349-01A-01R-1188-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3349-01A-01R-1188-07.dogs.bed.
# number sample :  3359
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3359-01A-01R-0864-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3359-01A-01R-0864-07.dogs.bed.
# number sample :  3374
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3374-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3374-01A-02R-1325-07.dogs.bed.
# number sample :  3383
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3383-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3383-01A-02R-1325-07.dogs.bed.
# number sample :  A8OU
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-A8OU-01A-11R-A37O-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-A8OU-01A-11R-A37O-07.dogs.bed.
# number sample :  3306
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3306-01A-01R-0864-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3306-01A-01R-0864-07.dogs.bed.
# number sample :  3311
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3311-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3311-01A-02R-1325-07.dogs.bed.
# number sample :  3331
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3331-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3331-01A-02R-1325-07.dogs.bed.
# number sample :  3358
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-A3-3358-11A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-A3-3358-11A-01R-1541-07.dogs.bed.
# number sample :  3382
# ...
# number sample :  5702
# []
# number sample :  5703
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5703-01A-11R-1541-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5703-11A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5703-01A-11R-1541-07.dogs.bed.
# number sample :  5703
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5703-01A-11R-1541-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5703-11A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5703-11A-01R-1541-07.dogs.bed.
# number sample :  5706
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5706-11A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5706-01A-11R-1541-07.dogs.bed.
# number sample :  5706
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5706-11A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5706-11A-01R-1541-07.dogs.bed.
# number sample :  5707
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5707.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5707-01A-11R-1541-07.dogs.bed.
# number sample :  5710
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5710-01A-11R-1672-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5710-01A-11R-1672-07.dogs.bed.
# number sample :  5711
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5711-01A-11R-1672-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5711-11A-01R-1672-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5711-01A-11R-1672-07.dogs.bed.
# number sample :  5711
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5711-01A-11R-1672-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5711-11A-01R-1672-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5711-11A-01R-1672-07.dogs.bed.
# number sample :  5712
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5712-01A-11R-1672-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5712-11A-01R-1672-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5712-01A-11R-1672-07.dogs.bed.
# number sample :  5712
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5712-01A-11R-1672-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5712-11A-01R-1672-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5712-11A-01R-1672-07.dogs.bed.
# number sample :  5713
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5713-01A-11R-1672-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5713-01A-11R-1672-07.dogs.bed.
# number sample :  4688
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4688-01A-01R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4688-01A-01R-1277-07.dogs.bed.
# number sample :  4690
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4690-01A-01R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4690-01A-01R-1277-07.dogs.bed.
# number sample :  4693
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4693-01A-01R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4693-01A-01R-1277-07.dogs.bed.
# number sample :  4694
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4694-01A-01R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4694-01A-01R-1277-07.dogs.bed.
# number sample :  4696
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4696-01A-01R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4696-01A-01R-1277-07.dogs.bed.
# number sample :  4697
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4697-01A-01R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4697-01A-01R-1277-07.dogs.bed.
# number sample :  4700
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4700-01A-02R-1541-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4700-11A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4700-01A-02R-1541-07.dogs.bed.
# number sample :  5084
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5084-01A-01R-1334-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5084-01A-01R-1334-07_downsampled.dogs.bed.
# number sample :  5085
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5085-01A-01R-1334-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5085-01A-01R-1334-07_downsampled.dogs.bed.
# number sample :  5098
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5098-01A-01R-1420-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5098-01A-01R-1420-07_downsampled.dogs.bed.
# number sample :  5121
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5121-01A-02R-1420-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5121-01A-02R-1420-07_downsampled.dogs.bed.
# number sample :  5402
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5402-01A-01R-1503-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5402-11A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5402-01A-01R-1503-07_downsampled.dogs.bed.
# number sample :  5691
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5691-11A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5691-11A-01R-1541-07_downsampled.dogs.bed.
# number sample :  5694
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5694-01A-11R-1541-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5694-11A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5694-11A-01R-1541-07_downsampled.dogs.bed.
# number sample :  5697
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5697-11A-01R-1541-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5697-01A-11R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5697-01A-11R-1541-07_downsampled.dogs.bed.
# number sample :  5705
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5705-01A-11R-1541-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5705-11A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5705-01A-11R-1541-07_downsampled.dogs.bed.
# number sample :  5709
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5709-11A-01R-1541-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5709-01A-11R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5709-01A-11R-1541-07_downsampled.dogs.bed.
# number sample :  4699
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4699-01A-01R-1277-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4699-01A-01R-1277-07_downsampled.dogs.bed.
# number sample :  4700
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4700-01A-02R-1541-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4700-11A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4700-11A-01R-1541-07_downsampled.dogs.bed.
# number sample :  4710
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4710-01A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4710-01A-01R-1503-07_downsampled.dogs.bed.
# number sample :  4811
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4811-01A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4811-01A-01R-1503-07_downsampled.dogs.bed.
# number sample :  5088
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5088-01A-01R-1334-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5088-01A-01R-1334-07_downsampled.dogs.bed.
# number sample :  5104
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5104-01A-01R-1420-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5104-01A-01R-1420-07_downsampled.dogs.bed.
# number sample :  5400
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5400-01A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5400-01A-01R-1503-07_downsampled.dogs.bed.
# number sample :  5402
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5402-01A-01R-1503-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5402-11A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5402-11A-01R-1503-07_downsampled.dogs.bed.
# number sample :  5695
# []
# number sample :  5698
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5698-01A-11R-1672-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5698-01A-11R-1672-07_downsampled.dogs.bed.
# number sample :  5705
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5705-01A-11R-1541-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5705-11A-01R-1541-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5705-11A-01R-1541-07_downsampled.dogs.bed.
# number sample :  4698
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4698-01A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4698-01A-01R-1503-07_downsampled.dogs.bed.
# number sample :  4706
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4706-01A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4706-01A-01R-1503-07_downsampled.dogs.bed.
# number sample :  4712
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4712-01A-01R-1503-07.bed', '/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4712-11A-02R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4712-11A-02R-1503-07_downsampled.dogs.bed.
# number sample :  4815
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4815-01A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4815-01A-01R-1503-07_downsampled.dogs.bed.
# number sample :  4816
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4816-01A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4816-01A-01R-1503-07_downsampled.dogs.bed.
# number sample :  4818
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4818-01A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4818-01A-01R-1503-07_downsampled.dogs.bed.
# number sample :  4827
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4827-01A-02R-1420-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4827-01A-02R-1420-07_downsampled.dogs.bed.
# number sample :  4834
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4834-01A-01R-1305-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4834-01A-01R-1305-07_downsampled.dogs.bed.
# number sample :  4852
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-4852-01A-01R-1503-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-4852-01A-01R-1503-07_downsampled.dogs.bed.
# number sample :  5075
# []
# number sample :  5077
# []
# number sample :  5081
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-B0-5081-01A-01R-1334-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-B0-5081-01A-01R-1334-07_downsampled.dogs.bed.
# number sample :  3427
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3427-01A-01R-0864-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3427-01A-01R-0864-07_downsampled.dogs.bed.
# number sample :  3443
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3443-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3443-01A-02R-1325-07_downsampled.dogs.bed.
# number sample :  3465
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AK-3465-01A-02R-1325-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AK-3465-01A-02R-1325-07_downsampled.dogs.bed.
# number sample :  3777
# ['/private/projects/kidney_rtt/filters_arriba_bed/TCGA-AS-3777-01A-01R-0864-07.bed']
# 'bedtools intersect' executed successfully. Output saved to /private/projects/kidney_rtt/intersect_all_samples/intersect_TCGA-AS-3777-01A-01R-0864-07_downsampled.dogs.bed.
# samples not found in arriba:  ['5695', '5574', '5906', 'A92I', 'A6C7', '3325', '3385', '3328', '3376', '3363', '3352', '3346', '3367', '3357', '3313', '3373', '3335', '3319', '4841', '5702', '5695', '5075', '5077']

# %%
# for finish filter (up to 21.6.23) with readthrough filterd 5465
artdeco_bed = "/home/ls/parshas/vscode/5465_processing/for_filter_by_fpkm/readthrough_filtered.bed"
arriba_bed = "/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CZ-5465-11A-01R-1503-07.bed"
output = "/home/ls/parshas/vscode/5465_processing/5465_intersect_readthrough_filter_arriba_filter.txt"
run_bedtools_intersect(artdeco_bed, arriba_bed, output)
zero_count, zero_percentage = count_lines_with_zero_last_column(output)
print("Number of lines with 0 in the last column:", zero_count)
print("Percentage of lines with 0 in the last column: {:.2f}%".format(zero_percentage))
print("Percentage of lines without 0 in the last column: {:.2f}%".format(100-zero_percentage))
# Out:
# 'bedtools intersect' executed successfully. Output saved to /home/ls/parshas/vscode/5465_processing/5465_intersect_readthrough_filter_arriba_filter.txt.
# Number of lines with 0 in the last column: 2325
# Percentage of lines with 0 in the last column: 50.92%
# Percentage of lines without 0 in the last column: 49.08%

# %%
# for finish filter (up to 21.6.23) with read_in filterd 5465
artdeco_bed = "/home/ls/parshas/vscode/5465_processing/for_filter_by_fpkm/read_in_filtered.bed"
arriba_bed = "/private/projects/kidney_rtt/filters_arriba_bed/TCGA-CZ-5465-11A-01R-1503-07.bed"
output = "/home/ls/parshas/vscode/5465_processing/5465_intersect_read_in_filter_arriba_filter.txt"
run_bedtools_intersect(artdeco_bed, arriba_bed, output)
zero_count, zero_percentage = count_lines_with_zero_last_column(output)
print("Number of lines with 0 in the last column:", zero_count)
print("Percentage of lines with 0 in the last column: {:.2f}%".format(zero_percentage))
print("Percentage of lines without 0 in the last column: {:.2f}%".format(100-zero_percentage))
# Out:
# 'bedtools intersect' executed successfully. Output saved to /home/ls/parshas/vscode/5465_processing/5465_intersect_read_in_filter_arriba_filter.txt.
# Number of lines with 0 in the last column: 2627
# Percentage of lines with 0 in the last column: 42.12%
# Percentage of lines without 0 in the last column: 57.88%

# %%
def find_rows_with_gene_id(bed_file, gene_id):
    matching_rows = []

    with open(bed_file, 'r') as file:
        for line in file:
            columns = line.split('\t')
            if len(columns) >= 4 and columns[3] == gene_id:
                matching_rows.append(columns)

    if len(matching_rows) > 1:
        print("found more than one line with this gene id")
    if len(matching_rows) == 0:
        print("gene id not found in readthrough.bed")
    return matching_rows[0]

# %%
def readthrough_readin_filter_and_to_bed(txt_file, readthrough_or_readin_bed_file): 
# the directory for the bed files = "/private/projects/kidney_rtt/readthrough_all_samples/"
    data = pyensembl.Genome(reference_name='GRCh38', annotation_name='my_genome_features',
                                gtf_path_or_url='/data01/private/resources/gencode.v34.GRCh38.annotation.gtf')
    data.index()  # parse GTF and construct database of genomic features
    df = pd.read_csv(txt_file, sep='\t')
    #count number of samples in this result
    number_of_samples = int((df.shape[1] - 2)/4)
    # create bed file for every sample
    column_list = df.columns.tolist()
    for i in range(number_of_samples):
        sample_column = column_list[(i * 4) + 2]
        split_list = sample_column.split(" ")
        sample_name = split_list[0]
        output_name = str(sample_name+".readthrough.bed")
        outputpath = os.path.join("/private/projects/kidney_rtt/readthrough_all_samples/",output_name)
        # Open the file for writing
        with open(outputpath, 'w') as bed_file:
            # Iterate over each row of the dataframe
            for index, row in df.iterrows():
                if(df.iloc[index, (i * 4) + 2] == 0 or df.iloc[index, (i * 4) + 3] == 0 or df.iloc[index, (i * 4) + 4] == 0): # filter gene count = 0 or gene FPKM = 0 or read_in/readthrough count = 0 
                    continue
                ens_id = df.iloc[index, 0]
                name = data.gene_name_of_gene_id(ens_id)
                bed_info = find_rows_with_gene_id(readthrough_or_readin_bed_file, ens_id)
                #calolate readthrough \ read-in FPKM
                z = df.iloc[index, (i * 4) + 5]
                y = df.iloc[index, (i * 4) + 3]
                fpkm = 2 ** (z + math.log2(y))
                # Write the chromosome name, start position, end position, gene name,
                # score and strand information to the BED file
                bed_file.write('\t'.join([
                    str(bed_info[0]),
                    str(bed_info[1]),
                    str(bed_info[2]),
                    str(name),
                    str(fpkm), # readthrough / read-in FPKM 
                    str(bed_info[5])
                ]))

# %%
#checks! need to be deleted
txt_file = "/private/projects/kidney_rtt/tcga_output/output_10/readthrough/readthrough.txt" 
txt_file = "/private/projects/kidney_rtt/tcga_5465_output_one_sample_running_before_downsample/readthrough/readthrough.txt"
df = pd.read_csv(txt_file, sep='\t')
#count number of samples in this result
number_of_samples = int((df.shape[1] - 2)/4)
print(number_of_samples)
column_list = df.columns.tolist()
for i in range(number_of_samples):
    sample_column = column_list[(i * 4) + 2]
    split_list = sample_column.split(" ")
    sample_name = split_list[0]
    output_name = str(sample_name+".readthrough.bed")
    outputpath = os.path.join("/private/projects/kidney_rtt/readthrough_all_samples/",output_name)
    print(sample_column)
    print(sample_name)
    print(output_name)
    print(outputpath)
    print(df.iloc[1, (i * 4) + 2])
    print(df.iloc[1, (i * 4) + 3])
    print(df.iloc[1, (i * 4) + 4])
    #calolate readthrough \ read-in FPKM
    z = df.iloc[1, (i * 4) + 5]
    y = df.iloc[1, (i * 4) + 3]
    fpkm = 2 ** (z + math.log2(y))
    print("FPKM, ", fpkm, "\n")
# Out:
# 1
# TCGA_CZ_5465_11A_01R_1503_07_half Gene Count
# TCGA_CZ_5465_11A_01R_1503_07_half
# TCGA_CZ_5465_11A_01R_1503_07_half.readthrough.bed
# /private/projects/kidney_rtt/readthrough_all_samples/TCGA_CZ_5465_11A_01R_1503_07_half.readthrough.bed
# 40.2106270943035
# 0.335
# 0.0
# FPKM,  0.008128971180987115

# %%
# find all the readthrough.txt files, create from them bed files and move to one directory for all 

directory_arriba = '/private/projects/kidney_rtt/filters_arriba_bed'
samples_not_found_in_arriba = []
# Function to loop over files in directory and subdirectories
def loop_files(directory):
    # Loop over files in directory and subdirectories
    for root, _, files in os.walk(directory):
        for filename in files:
            if filename == "readthrough.txt":
                file_path = os.path.join(root, filename)
                parent_directory = os.path.dirname(root)  # Get the parent directory of root
                readthrough_bed_path = os.path.join(parent_directory, "preprocess_files/readthrough.bed")
                print(file_path)
                print(parent_directory)
                print(readthrough_bed_path, "\n\n")
                readthrough_readin_filter_and_to_bed(file_path, readthrough_bed_path)
                


loop_files("/private/projects/kidney_rtt/tcga_output")
loop_files("/private/projects/kidney_rtt/artdeco_run")
# Out:
# /private/projects/kidney_rtt/tcga_output/small_files/output_1/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/small_files/output_1
# /private/projects/kidney_rtt/tcga_output/small_files/output_1/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/small_files/output_2/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/small_files/output_2
# /private/projects/kidney_rtt/tcga_output/small_files/output_2/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/small_files/output_3/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/small_files/output_3
# /private/projects/kidney_rtt/tcga_output/small_files/output_3/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/small_files/output_4
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/small_files/output_5/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/small_files/output_5
# /private/projects/kidney_rtt/tcga_output/small_files/output_5/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/small_files/output_6/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/small_files/output_6
# /private/projects/kidney_rtt/tcga_output/small_files/output_6/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/part_4/output_5465_RTdis0/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/part_4/output_5465_RTdis0
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/part_4/output_5465_RTdis0/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/part_4/output_4564_RTdis0_try2/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/part_4/output_4564_RTdis0_try2
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/part_4/output_4564_RTdis0_try2/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_1/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_1
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_1/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_2/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_2
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_2/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_3/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_3
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_3/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_4/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_4
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_4/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_8/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_8
# /private/projects/kidney_rtt/tcga_output/output_8/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_10/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_10
# /private/projects/kidney_rtt/tcga_output/output_10/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_2/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_2
# /private/projects/kidney_rtt/tcga_output/output_2/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3425-01A-02R-1277-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3425-01A-02R-1277-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3425-01A-02R-1277-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3426-01A-02R-1325-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3426-01A-02R-1325-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3426-01A-02R-1325-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3428-01A-02R-1277-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3428-01A-02R-1277-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3428-01A-02R-1277-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3431-01A-02R-1277-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3431-01A-02R-1277-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3431-01A-02R-1277-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3433-01A-02R-1277-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3433-01A-02R-1277-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3433-01A-02R-1277-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3436-01A-02R-1325-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3436-01A-02R-1325-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3436-01A-02R-1325-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3445-01A-02R-1277-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3445-01A-02R-1277-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3445-01A-02R-1277-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3447-01A-01R-1766-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3447-01A-01R-1766-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3447-01A-01R-1766-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3450-01A-02R-1277-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3450-01A-02R-1277-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3450-01A-02R-1277-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3453-01A-02R-1277-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3453-01A-02R-1277-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3453-01A-02R-1277-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3454-01A-02R-1277-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3454-01A-02R-1277-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3454-01A-02R-1277-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3455-01A-01R-0864-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3455-01A-01R-0864-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3455-01A-01R-0864-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3456-01A-02R-1325-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3456-01A-02R-1325-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3456-01A-02R-1325-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3458-01A-01R-1503-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3458-01A-01R-1503-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3458-01A-01R-1503-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3460-01A-02R-1277-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3460-01A-02R-1277-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3460-01A-02R-1277-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3461-01A-02R-1277-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3461-01A-02R-1277-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3461-01A-02R-1277-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-3923-01A-02R-1325-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-3923-01A-02R-1325-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-3923-01A-02R-1325-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-3924-01A-02R-1325-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-3924-01A-02R-1325-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-3924-01A-02R-1325-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-4099-01A-02R-1188-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-4099-01A-02R-1188-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-4099-01A-02R-1188-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-4101-01A-02R-1277-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-4101-01A-02R-1277-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-4101-01A-02R-1277-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-5633-01A-01R-1541-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-5633-01A-01R-1541-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-5633-01A-01R-1541-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-5635-01A-01R-1541-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-5635-01A-01R-1541-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-5635-01A-01R-1541-07_output/preprocess_files/readthrough.bed
#
#
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-5636-01A-02R-1541-07_output/readthrough/readthrough.txt
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-5636-01A-02R-1541-07_output
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-5636-01A-02R-1541-07_output/preprocess_files/readthrough.bed

# %%
# count how many samples are
directory_arriba = '/private/projects/kidney_rtt/filters_arriba_bed'
samples_not_found_in_arriba = []
# Function to loop over files in directory and subdirectories

def loop_files(directory):
    count = 0
    # Loop over files in directory and subdirectories
    with open(all_samples.txt, 'r') as file:
        for root, _, files in os.walk(directory):
            for filename in files:
                if filename.endswith(".dogs.bed"):
                    file_path = os.path.join(root, filename)
                    df = pd.read_csv(file_path, sep='\t')
                    print(file_path)
                    #count number of samples in this result
                    number_of_samples = int((df.shape[1] - 2)/4)
                    count += number_of_samples
    print("count ", count)
                


loop_files("/private/projects/kidney_rtt/tcga_output")
loop_files("/private/projects/kidney_rtt/artdeco_run")
loop_files("/private/projects/kidney_rtt/dogs/only_dogs")
# Out:
# /private/projects/kidney_rtt/tcga_output/small_files/output_1/dogs/TCGA-G6-A8L7-01A-11R-A37O-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_1/dogs/TCGA-AS-3778-01A-01R-A32Z-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_1/dogs/TCGA-A3-A8OX-01A-11R-A37O-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_1/dogs/TCGA-A3-3372-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_1/dogs/TCGA-A3-3326-01A-01R-0864-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_1/dogs/TCGA-A3-3320-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_1/dogs/TCGA-A3-3323-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_1/dogs/TCGA-A3-3387-11A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_1/dogs/TCGA-A3-3322-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_2/dogs/TCGA-AK-3434-01A-02R-1277-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_2/dogs/TCGA-AK-3429-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_2/dogs/TCGA-AK-3451-01A-02R-1188-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_2/dogs/TCGA-AK-3440-01A-02R-1277-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_3/dogs/TCGA-B0-5812-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_3/dogs/TCGA-B0-4712-01A-01R-1503-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_3/dogs/TCGA-B0-4703-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_3/dogs/TCGA-B0-5400-01A-01R-1503-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_3/dogs/TCGA-B0-5709-11A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_3/dogs/TCGA-B0-5700-01A-11R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_3/dogs/TCGA-B0-4823-01A-02R-1420-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_3/dogs/TCGA-B0-4833-01A-01R-1305-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_3/dogs/TCGA-B0-5399-01A-01R-1503-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_3/dogs/TCGA-B0-4842-01A-02R-1420-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_3/dogs/TCGA-B0-5697-11A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_3/dogs/TCGA-B0-4814-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_3/dogs/TCGA-B0-4810-01A-01R-1503-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_3/dogs/TCGA-B0-5695-01A-11R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/dogs/TCGA-BP-4337-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/dogs/TCGA-BP-4164-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/dogs/TCGA-BP-5168-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/dogs/TCGA-BP-4807-01A-01R-1305-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/dogs/TCGA-BP-4804-01A-02R-1305-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/dogs/TCGA-BP-4771-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/dogs/TCGA-BP-4327-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/dogs/TCGA-BP-5175-01A-01R-1426-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/dogs/TCGA-BP-4329-01A-02R-1289-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/dogs/TCGA-BP-4173-01A-02R-1289-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/dogs/TCGA-BP-4344-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/dogs/TCGA-BP-4177-01A-02R-1420-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/dogs/TCGA-BP-4334-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/dogs/TCGA-BP-4170-01A-02R-1289-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/dogs/TCGA-BP-4341-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/dogs/TCGA-BP-4332-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/dogs/TCGA-BP-5181-01A-01R-1426-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_4/dogs/TCGA-BP-4765-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_5/dogs/TCGA-B8-A54D-01A-21R-A266-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_5/dogs/TCGA-B8-5552-11A-01R-1672-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_5/dogs/TCGA-B2-4102-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_5/dogs/TCGA-B4-5832-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_5/dogs/TCGA-B8-4620-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_5/dogs/TCGA-B8-5546-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_5/dogs/TCGA-B2-4098-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_6/dogs/TCGA-DV-A4W0-05A-11R-A266-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_6/dogs/TCGA-CZ-5987-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_6/dogs/TCGA-CJ-4894-01A-01R-1305-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_6/dogs/TCGA-CZ-5986-11A-01R-1672-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_6/dogs/TCGA-DV-5576-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_6/dogs/TCGA-CZ-5985-11A-01R-1672-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_6/dogs/TCGA-CJ-5675-01A-11R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_6/dogs/TCGA-MM-A563-01A-11R-A266-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_6/dogs/TCGA-CJ-4644-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_6/dogs/TCGA-CW-5588-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_6/dogs/TCGA-CW-5584-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_6/dogs/TCGA-CZ-5988-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_6/dogs/TCGA-EU-5904-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_6/dogs/TCGA-CJ-6033-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_6/dogs/TCGA-CJ-4869-01A-02R-1426-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/small_files/output_6/dogs/TCGA-CJ-4908-01A-01R-1426-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/part_4/output_5465_RTdis0/dogs/TCGA-CZ-5465-11A-01R-1503-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/part_4/output_4564_RTdis0_try2/dogs/TCGA-CZ-5465-11A-01R-1503-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_1/dogs/TCGA-A3-3380-01A-01R-0864-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_1/dogs/TCGA-B0-5088-01A-01R-1334-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_1/dogs/TCGA-B8-4621-01A-01R-1503-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_1/dogs/TCGA-B0-5104-01A-01R-1420-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_1/dogs/TCGA-A3-3370-01A-02R-1420-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_1/dogs/TCGA-B0-5084-01A-01R-1334-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_2/dogs/TCGA-BP-4972-01A-01R-1334-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_2/dogs/TCGA-BP-5201-01A-01R-1426-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_2/dogs/TCGA-BP-4970-01A-01R-1334-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_2/dogs/TCGA-BP-4964-01A-01R-1334-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_2/dogs/TCGA-BP-4965-01A-01R-1334-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_2/dogs/TCGA-BP-4983-01A-01R-1334-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_2/dogs/TCGA-BP-4971-01A-01R-1334-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_2/dogs/TCGA-BP-4960-01A-01R-1334-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_3/dogs/TCGA-CJ-4918-01A-01R-1426-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_3/dogs/TCGA-CJ-4916-01A-01R-1426-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_3/dogs/TCGA-CJ-5678-11A-01R-1541-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_3/dogs/TCGA-CJ-4899-01A-01R-1334-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_3/dogs/TCGA-CJ-4902-01A-01R-1426-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_3/dogs/TCGA-CJ-4903-01A-01R-1426-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_3/dogs/TCGA-CJ-4897-01A-03R-1426-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_4/dogs/TCGA-CZ-5984-01A-11R-1672-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_4/dogs/TCGA-CZ-5466-11A-01R-1503-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_4/dogs/TCGA-CZ-4854-01A-01R-1305-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_4/dogs/TCGA-CZ-4853-01A-01R-1426-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_4/dogs/TCGA-CZ-5454-01A-01R-1503-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_4/dogs/TCGA-CZ-4859-01A-02R-1426-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_4/dogs/TCGA-CZ-4864-11A-01R-1503-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/all_subsample_bam/output_4/dogs/TCGA-CZ-5465-11A-01R-1503-07.downsample.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_8/dogs/TCGA-DV-A4VZ-01A-11R-A266-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_8/dogs/TCGA-DV-5566-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_8/dogs/TCGA-DV-5567-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_8/dogs/TCGA-DV-A4W0-01A-11R-A266-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_8/dogs/TCGA-DV-5565-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_8/dogs/TCGA-DV-A4VX-01A-11R-A266-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_8/dogs/TCGA-DV-5574-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_8/dogs/TCGA-DV-5569-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_8/dogs/TCGA-DV-5568-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_8/dogs/TCGA-DV-5576-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_8/dogs/TCGA-DV-A4W0-05A-11R-A266-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_8/dogs/TCGA-DV-5575-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_8/dogs/TCGA-DV-5573-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_10/dogs/TCGA-MM-A84U-01A-11R-A37O-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_10/dogs/TCGA-EU-5905-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_10/dogs/TCGA-EU-5907-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_10/dogs/TCGA-EU-5906-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_10/dogs/TCGA-MM-A564-01A-11R-A266-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_10/dogs/TCGA-G6-A8L8-01A-21R-A37O-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_10/dogs/TCGA-T7-A92I-01A-11R-A37O-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_10/dogs/TCGA-GK-A6C7-01A-11R-A33J-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_10/dogs/TCGA-G6-A5PC-01A-11R-A33J-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_10/dogs/TCGA-MW-A4EC-01A-11R-A266-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_10/dogs/TCGA-G6-A8L6-01A-11R-A37O-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_2/dogs/TCGA-A3-3325-01A-01R-0864-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_2/dogs/TCGA-A3-3385-01A-02R-1420-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_2/dogs/TCGA-A3-3328-01A-01R-0864-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_2/dogs/TCGA-A3-3376-01A-02R-1420-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_2/dogs/TCGA-A3-3363-01A-01R-0864-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_2/dogs/TCGA-A3-3352-01A-01R-0864-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_2/dogs/TCGA-A3-3346-01A-01R-1766-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_2/dogs/TCGA-A3-3367-01A-02R-1420-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_2/dogs/TCGA-A3-3357-01A-02R-1420-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_2/dogs/TCGA-A3-3313-01A-02R-1325-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_2/dogs/TCGA-A3-3373-01A-02R-1420-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_2/dogs/TCGA-A3-3335-01A-01R-0864-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_2/dogs/TCGA-A3-3358-01A-01R-1541-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_2/dogs/TCGA-A3-3319-01A-02R-1325-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3425-01A-02R-1277-07_output/dogs/TCGA-AK-3425-01A-02R-1277-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3426-01A-02R-1325-07_output/dogs/TCGA-AK-3426-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3428-01A-02R-1277-07_output/dogs/TCGA-AK-3428-01A-02R-1277-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3431-01A-02R-1277-07_output/dogs/TCGA-AK-3431-01A-02R-1277-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3433-01A-02R-1277-07_output/dogs/TCGA-AK-3433-01A-02R-1277-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3436-01A-02R-1325-07_output/dogs/TCGA-AK-3436-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3445-01A-02R-1277-07_output/dogs/TCGA-AK-3445-01A-02R-1277-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3447-01A-01R-1766-07_output/dogs/TCGA-AK-3447-01A-01R-1766-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3450-01A-02R-1277-07_output/dogs/TCGA-AK-3450-01A-02R-1277-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3453-01A-02R-1277-07_output/dogs/TCGA-AK-3453-01A-02R-1277-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3454-01A-02R-1277-07_output/dogs/TCGA-AK-3454-01A-02R-1277-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3455-01A-01R-0864-07_output/dogs/TCGA-AK-3455-01A-01R-0864-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3456-01A-02R-1325-07_output/dogs/TCGA-AK-3456-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3458-01A-01R-1503-07_output/dogs/TCGA-AK-3458-01A-01R-1503-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3460-01A-02R-1277-07_output/dogs/TCGA-AK-3460-01A-02R-1277-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-AK-3461-01A-02R-1277-07_output/dogs/TCGA-AK-3461-01A-02R-1277-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-3923-01A-02R-1325-07_output/dogs/TCGA-B2-3923-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-3924-01A-02R-1325-07_output/dogs/TCGA-B2-3924-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-4099-01A-02R-1188-07_output/dogs/TCGA-B2-4099-01A-02R-1188-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-4101-01A-02R-1277-07_output/dogs/TCGA-B2-4101-01A-02R-1277-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-5633-01A-01R-1541-07_output/dogs/TCGA-B2-5633-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-5635-01A-01R-1541-07_output/dogs/TCGA-B2-5635-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-5636-01A-02R-1541-07_output/dogs/TCGA-B2-5636-01A-02R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-5639-01A-01R-1541-07_output/dogs/TCGA-B2-5639-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-5641-01A-01R-1541-07_output/dogs/TCGA-B2-5641-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-5641-11A-01R-1541-07_output/dogs/TCGA-B2-5641-11A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/tcga_output/output_new/TCGA-B2-A4SR-01A-11R-A266-07_output/dogs/TCGA-B2-A4SR-01A-11R-A266-07.dogs.bed
# count  164
# /private/projects/kidney_rtt/artdeco_run/part_2_small/TCGA-EU-5905-01A-11R-1672-07_output/dogs/TCGA-EU-5905-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_2_small/TCGA-MM-A564-01A-11R-A266-07_output/dogs/TCGA-MM-A564-01A-11R-A266-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_2_small/TCGA-DV-5565-01A-01R-1541-07_output/dogs/TCGA-DV-5565-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_2_small/TCGA-DV-5567-01A-01R-1541-07_output/dogs/TCGA-DV-5567-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_2_small/TCGA-DV-5569-01A-01R-1541-07_output/dogs/TCGA-DV-5569-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_2_small/TCGA-DV-5575-01A-01R-1541-07_output/dogs/TCGA-DV-5575-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_2_small/TCGA-DV-A4VZ-01A-11R-A266-07_output/dogs/TCGA-DV-A4VZ-01A-11R-A266-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_2_small/TCGA-EU-5907-01A-11R-1672-07_output/dogs/TCGA-EU-5907-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_2_small/TCGA-MW-A4EC-01A-11R-A266-07_output/dogs/TCGA-MW-A4EC-01A-11R-A266-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_2_small/TCGA-DV-5566-01A-01R-1541-07_output/dogs/TCGA-DV-5566-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_2_small/TCGA-DV-5568-01A-01R-1541-07_output/dogs/TCGA-DV-5568-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_2_small/TCGA-DV-5573-01A-01R-1541-07_output/dogs/TCGA-DV-5573-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_2_small/TCGA-DV-A4VX-01A-11R-A266-07_output/dogs/TCGA-DV-A4VX-01A-11R-A266-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_2_small/TCGA-DV-A4W0-01A-11R-A266-07_output/dogs/TCGA-DV-A4W0-01A-11R-A266-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-A6NN-01A-12R-A33J-07_output/dogs/TCGA-A3-A6NN-01A-12R-A33J-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-B8-A7U6-01A-12R-A37O-07_output/dogs/TCGA-B8-A7U6-01A-12R-A37O-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-G6-A5PC-01A-11R-A33J-07_output/dogs/TCGA-G6-A5PC-01A-11R-A33J-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-MM-A84U-01A-11R-A37O-07_output/dogs/TCGA-MM-A84U-01A-11R-A37O-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-6D-AA2E-01A-11R-A37O-07_output/dogs/TCGA-6D-AA2E-01A-11R-A37O-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3308-01A-02R-1325-07_output/dogs/TCGA-A3-3308-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3317-01A-02R-1325-07_output/dogs/TCGA-A3-3317-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3329-01A-01R-0864-07_output/dogs/TCGA-A3-3329-01A-01R-0864-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3347-01A-02R-1325-07_output/dogs/TCGA-A3-3347-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3351-01A-02R-1325-07_output/dogs/TCGA-A3-3351-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3362-01A-02R-1325-07_output/dogs/TCGA-A3-3362-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3378-01A-02R-1325-07_output/dogs/TCGA-A3-3378-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-A6NI-01A-11R-A33J-07_output/dogs/TCGA-A3-A6NI-01A-11R-A33J-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3387-01A-01R-1541-07_output/dogs/TCGA-A3-3387-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-A6NJ-01A-12R-A33J-07_output/dogs/TCGA-A3-A6NJ-01A-12R-A33J-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-A8OW-01A-11R-A37O-07_output/dogs/TCGA-A3-A8OW-01A-11R-A37O-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-B8-A8YJ-01A-13R-A39I-07_output/dogs/TCGA-B8-A8YJ-01A-13R-A39I-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-G6-A8L8-01A-21R-A37O-07_output/dogs/TCGA-G6-A8L8-01A-21R-A37O-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-3Z-A93Z-01A-11R-A37O-07_output/dogs/TCGA-3Z-A93Z-01A-11R-A37O-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3307-01A-01R-0864-07_output/dogs/TCGA-A3-3307-01A-01R-0864-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3316-01A-01R-0864-07_output/dogs/TCGA-A3-3316-01A-01R-0864-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3324-01A-02R-1325-07_output/dogs/TCGA-A3-3324-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3343-01A-01R-0864-07_output/dogs/TCGA-A3-3343-01A-01R-0864-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3349-01A-01R-1188-07_output/dogs/TCGA-A3-3349-01A-01R-1188-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3359-01A-01R-0864-07_output/dogs/TCGA-A3-3359-01A-01R-0864-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3374-01A-02R-1325-07_output/dogs/TCGA-A3-3374-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3383-01A-02R-1325-07_output/dogs/TCGA-A3-3383-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-A8OU-01A-11R-A37O-07_output/dogs/TCGA-A3-A8OU-01A-11R-A37O-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-G6-A8L6-01A-11R-A37O-07_output/dogs/TCGA-G6-A8L6-01A-11R-A37O-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3306-01A-01R-0864-07_output/dogs/TCGA-A3-3306-01A-01R-0864-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3311-01A-02R-1325-07_output/dogs/TCGA-A3-3311-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3331-01A-02R-1325-07_output/dogs/TCGA-A3-3331-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3358-11A-01R-1541-07_output/dogs/TCGA-A3-3358-11A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-3382-01A-02R-1325-07_output/dogs/TCGA-A3-3382-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-A6NL-01A-11R-A33J-07_output/dogs/TCGA-A3-A6NL-01A-11R-A33J-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-A8CQ-01A-11R-A37O-07_output/dogs/TCGA-A3-A8CQ-01A-11R-A37O-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-A3-A8OV-01A-11R-A37O-07_output/dogs/TCGA-A3-A8OV-01A-11R-A37O-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_3_small/TCGA-B8-A54K-01A-11R-A33J-07_output/dogs/TCGA-B8-A54K-01A-11R-A33J-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4701-01A-01R-1277-07_output/dogs/TCGA-B0-4701-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4707-01A-01R-1277-07_output/dogs/TCGA-B0-4707-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4713-01A-01R-1277-07_output/dogs/TCGA-B0-4713-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4714-01A-01R-1277-07_output/dogs/TCGA-B0-4714-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4718-01A-01R-1277-07_output/dogs/TCGA-B0-4718-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4817-01A-01R-1277-07_output/dogs/TCGA-B0-4817-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4819-01A-01R-1277-07_output/dogs/TCGA-B0-4819-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4821-01A-01R-1503-07_output/dogs/TCGA-B0-4821-01A-01R-1503-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4822-01A-01R-1277-07_output/dogs/TCGA-B0-4822-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4824-01A-01R-1277-07_output/dogs/TCGA-B0-4824-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4828-01A-01R-1277-07_output/dogs/TCGA-B0-4828-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4836-01A-01R-1305-07_output/dogs/TCGA-B0-4836-01A-01R-1305-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4837-01A-01R-1305-07_output/dogs/TCGA-B0-4837-01A-01R-1305-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4838-01A-01R-1305-07_output/dogs/TCGA-B0-4838-01A-01R-1305-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4839-01A-01R-1305-07_output/dogs/TCGA-B0-4839-01A-01R-1305-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4841-01A-01R-1277-07_output/dogs/TCGA-B0-4841-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4843-01A-01R-1277-07_output/dogs/TCGA-B0-4843-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4844-01A-01R-1277-07_output/dogs/TCGA-B0-4844-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4845-01A-01R-1277-07_output/dogs/TCGA-B0-4845-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4846-01A-01R-1277-07_output/dogs/TCGA-B0-4846-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4847-01A-01R-1277-07_output/dogs/TCGA-B0-4847-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4848-01A-01R-1277-07_output/dogs/TCGA-B0-4848-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4849-01A-01R-1277-07_output/dogs/TCGA-B0-4849-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4945-01A-01R-1420-07_output/dogs/TCGA-B0-4945-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5080-01A-01R-1503-07_output/dogs/TCGA-B0-5080-01A-01R-1503-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5083-01A-02R-1420-07_output/dogs/TCGA-B0-5083-01A-02R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5092-01A-01R-1420-07_output/dogs/TCGA-B0-5092-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5094-01A-01R-1420-07_output/dogs/TCGA-B0-5094-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5095-01A-01R-1420-07_output/dogs/TCGA-B0-5095-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5096-01A-01R-1420-07_output/dogs/TCGA-B0-5096-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5097-01A-01R-1420-07_output/dogs/TCGA-B0-5097-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5099-01A-01R-1420-07_output/dogs/TCGA-B0-5099-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5100-01A-01R-1420-07_output/dogs/TCGA-B0-5100-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5102-01A-01R-1420-07_output/dogs/TCGA-B0-5102-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5106-01A-01R-1420-07_output/dogs/TCGA-B0-5106-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5107-01A-01R-1420-07_output/dogs/TCGA-B0-5107-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5108-01A-01R-1420-07_output/dogs/TCGA-B0-5108-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5109-01A-02R-1420-07_output/dogs/TCGA-B0-5109-01A-02R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5110-01A-01R-1420-07_output/dogs/TCGA-B0-5110-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5113-01A-01R-1420-07_output/dogs/TCGA-B0-5113-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5115-01A-01R-1420-07_output/dogs/TCGA-B0-5115-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5116-01A-02R-1420-07_output/dogs/TCGA-B0-5116-01A-02R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5117-01A-01R-1420-07_output/dogs/TCGA-B0-5117-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5119-01A-02R-1420-07_output/dogs/TCGA-B0-5119-01A-02R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5120-01A-01R-1420-07_output/dogs/TCGA-B0-5120-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5690-01A-11R-1541-07_output/dogs/TCGA-B0-5690-01A-11R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5690-11A-01R-1541-07_output/dogs/TCGA-B0-5690-11A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5691-01A-11R-1541-07_output/dogs/TCGA-B0-5691-01A-11R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5692-01A-11R-1541-07_output/dogs/TCGA-B0-5692-01A-11R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5693-01A-11R-1541-07_output/dogs/TCGA-B0-5693-01A-11R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5694-01A-11R-1541-07_output/dogs/TCGA-B0-5694-01A-11R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5696-01A-11R-1541-07_output/dogs/TCGA-B0-5696-01A-11R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5696-11A-01R-1541-07_output/dogs/TCGA-B0-5696-11A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5699-01A-11R-1541-07_output/dogs/TCGA-B0-5699-01A-11R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5699-11A-01R-1541-07_output/dogs/TCGA-B0-5699-11A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5701-01A-11R-1541-07_output/dogs/TCGA-B0-5701-01A-11R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5701-11A-01R-1541-07_output/dogs/TCGA-B0-5701-11A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5702-01A-11R-1541-07_output/dogs/TCGA-B0-5702-01A-11R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5703-01A-11R-1541-07_output/dogs/TCGA-B0-5703-01A-11R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5703-11A-01R-1541-07_output/dogs/TCGA-B0-5703-11A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5706-01A-11R-1541-07_output/dogs/TCGA-B0-5706-01A-11R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5706-11A-01R-1541-07_output/dogs/TCGA-B0-5706-11A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5707-01A-11R-1541-07_output/dogs/TCGA-B0-5707-01A-11R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5710-01A-11R-1672-07_output/dogs/TCGA-B0-5710-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5711-01A-11R-1672-07_output/dogs/TCGA-B0-5711-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5711-11A-01R-1672-07_output/dogs/TCGA-B0-5711-11A-01R-1672-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5712-01A-11R-1672-07_output/dogs/TCGA-B0-5712-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5712-11A-01R-1672-07_output/dogs/TCGA-B0-5712-11A-01R-1672-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-5713-01A-11R-1672-07_output/dogs/TCGA-B0-5713-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4688-01A-01R-1277-07_output/dogs/TCGA-B0-4688-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4690-01A-01R-1277-07_output/dogs/TCGA-B0-4690-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4693-01A-01R-1277-07_output/dogs/TCGA-B0-4693-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4694-01A-01R-1277-07_output/dogs/TCGA-B0-4694-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4696-01A-01R-1277-07_output/dogs/TCGA-B0-4696-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4697-01A-01R-1277-07_output/dogs/TCGA-B0-4697-01A-01R-1277-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_4_small/TCGA-B0-4700-01A-02R-1541-07_output/dogs/TCGA-B0-4700-01A-02R-1541-07.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5084-01A-01R-1334-07_downsampled_output/dogs/TCGA-B0-5084-01A-01R-1334-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5085-01A-01R-1334-07_downsampled_output/dogs/TCGA-B0-5085-01A-01R-1334-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5098-01A-01R-1420-07_downsampled_output/dogs/TCGA-B0-5098-01A-01R-1420-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5121-01A-02R-1420-07_downsampled_output/dogs/TCGA-B0-5121-01A-02R-1420-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5402-01A-01R-1503-07_downsampled_output/dogs/TCGA-B0-5402-01A-01R-1503-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5691-11A-01R-1541-07_downsampled_output/dogs/TCGA-B0-5691-11A-01R-1541-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5694-11A-01R-1541-07_downsampled_output/dogs/TCGA-B0-5694-11A-01R-1541-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5697-01A-11R-1541-07_downsampled_output/dogs/TCGA-B0-5697-01A-11R-1541-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5705-01A-11R-1541-07_downsampled_output/dogs/TCGA-B0-5705-01A-11R-1541-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5709-01A-11R-1541-07_downsampled_output/dogs/TCGA-B0-5709-01A-11R-1541-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-4699-01A-01R-1277-07_downsampled_output/dogs/TCGA-B0-4699-01A-01R-1277-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-4700-11A-01R-1541-07_downsampled_output/dogs/TCGA-B0-4700-11A-01R-1541-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-4710-01A-01R-1503-07_downsampled_output/dogs/TCGA-B0-4710-01A-01R-1503-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-4811-01A-01R-1503-07_downsampled_output/dogs/TCGA-B0-4811-01A-01R-1503-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5088-01A-01R-1334-07_downsampled_output/dogs/TCGA-B0-5088-01A-01R-1334-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5104-01A-01R-1420-07_downsampled_output/dogs/TCGA-B0-5104-01A-01R-1420-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5400-01A-01R-1503-07_downsampled_output/dogs/TCGA-B0-5400-01A-01R-1503-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5402-11A-01R-1503-07_downsampled_output/dogs/TCGA-B0-5402-11A-01R-1503-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5695-01A-11R-1541-07_downsampled_output/dogs/TCGA-B0-5695-01A-11R-1541-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5698-01A-11R-1672-07_downsampled_output/dogs/TCGA-B0-5698-01A-11R-1672-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5705-11A-01R-1541-07_downsampled_output/dogs/TCGA-B0-5705-11A-01R-1541-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-4698-01A-01R-1503-07_downsampled_output/dogs/TCGA-B0-4698-01A-01R-1503-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-4706-01A-01R-1503-07_downsampled_output/dogs/TCGA-B0-4706-01A-01R-1503-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-4712-11A-02R-1503-07_downsampled_output/dogs/TCGA-B0-4712-11A-02R-1503-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-4815-01A-01R-1503-07_downsampled_output/dogs/TCGA-B0-4815-01A-01R-1503-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-4816-01A-01R-1503-07_downsampled_output/dogs/TCGA-B0-4816-01A-01R-1503-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-4818-01A-01R-1503-07_downsampled_output/dogs/TCGA-B0-4818-01A-01R-1503-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-4827-01A-02R-1420-07_downsampled_output/dogs/TCGA-B0-4827-01A-02R-1420-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-4834-01A-01R-1305-07_downsampled_output/dogs/TCGA-B0-4834-01A-01R-1305-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-4852-01A-01R-1503-07_downsampled_output/dogs/TCGA-B0-4852-01A-01R-1503-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5075-01A-01R-1334-07_downsampled_output/dogs/TCGA-B0-5075-01A-01R-1334-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5077-01A-01R-1334-07_downsampled_output/dogs/TCGA-B0-5077-01A-01R-1334-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_1/TCGA-B0-5081-01A-01R-1334-07_downsampled_output/dogs/TCGA-B0-5081-01A-01R-1334-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_2/TCGA-AK-3427-01A-01R-0864-07_downsampled_output/dogs/TCGA-AK-3427-01A-01R-0864-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_2/TCGA-AK-3443-01A-02R-1325-07_downsampled_output/dogs/TCGA-AK-3443-01A-02R-1325-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_2/TCGA-AK-3465-01A-02R-1325-07_downsampled_output/dogs/TCGA-AK-3465-01A-02R-1325-07_downsampled.dogs.bed
# /private/projects/kidney_rtt/artdeco_run/part_2/TCGA-AS-3777-01A-01R-0864-07_downsampled_output/dogs/TCGA-AS-3777-01A-01R-0864-07_downsampled.dogs.bed
# count  165
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B4-5834-01A-11R-1672-07_output/dogs/TCGA-B4-5834-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B4-5836-01A-11R-1672-07_output/dogs/TCGA-B4-5836-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B4-5838-01A-11R-1672-07_output/dogs/TCGA-B4-5838-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B4-5843-01A-11R-1672-07_output/dogs/TCGA-B4-5843-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B4-5844-01A-11R-1672-07_output/dogs/TCGA-B4-5844-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-4143-01A-01R-1188-07_output/dogs/TCGA-B8-4143-01A-01R-1188-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-4146-01B-11R-1672-07_output/dogs/TCGA-B8-4146-01B-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-4148-01A-02R-1325-07_output/dogs/TCGA-B8-4148-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-4151-01A-01R-1188-07_output/dogs/TCGA-B8-4151-01A-01R-1188-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-4153-01B-11R-1672-07_output/dogs/TCGA-B8-4153-01B-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-4154-01A-01R-1188-07_output/dogs/TCGA-B8-4154-01A-01R-1188-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-4619-01A-02R-1325-07_output/dogs/TCGA-B8-4619-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-4619-11A-01R-1758-07_output/dogs/TCGA-B8-4619-11A-01R-1758-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-4620-11A-01R-1758-07_output/dogs/TCGA-B8-4620-11A-01R-1758-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-4622-01A-02R-1277-07_output/dogs/TCGA-B8-4622-01A-02R-1277-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-4622-11A-01R-1758-07_output/dogs/TCGA-B8-4622-11A-01R-1758-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-5158-01A-01R-1420-07_output/dogs/TCGA-B8-5158-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-5165-01A-01R-1420-07_output/dogs/TCGA-B8-5165-01A-01R-1420-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-5545-01A-01R-1672-07_output/dogs/TCGA-B8-5545-01A-01R-1672-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-5549-11A-01R-1541-07_output/dogs/TCGA-B8-5549-11A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-5550-01A-01R-1541-07_output/dogs/TCGA-B8-5550-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-5551-01A-01R-1541-07_output/dogs/TCGA-B8-5551-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-5552-01B-11R-1672-07_output/dogs/TCGA-B8-5552-01B-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-5553-01A-01R-1541-07_output/dogs/TCGA-B8-5553-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-A54E-01A-11R-A266-07_output/dogs/TCGA-B8-A54E-01A-11R-A266-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-A54F-01A-11R-A266-07_output/dogs/TCGA-B8-A54F-01A-11R-A266-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-B8-A54G-01A-11R-A266-07_output/dogs/TCGA-B8-A54G-01A-11R-A266-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4158-01A-02R-1289-07_output/dogs/TCGA-BP-4158-01A-02R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4159-01A-02R-1289-07_output/dogs/TCGA-BP-4159-01A-02R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4160-01A-02R-1289-07_output/dogs/TCGA-BP-4160-01A-02R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4161-01A-02R-1325-07_output/dogs/TCGA-BP-4161-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4162-01A-02R-1325-07_output/dogs/TCGA-BP-4162-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4163-01A-02R-1325-07_output/dogs/TCGA-BP-4163-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4165-01A-02R-1289-07_output/dogs/TCGA-BP-4165-01A-02R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4167-01A-02R-1325-07_output/dogs/TCGA-BP-4167-01A-02R-1325-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4174-01A-02R-1289-07_output/dogs/TCGA-BP-4174-01A-02R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4176-01A-02R-1289-07_output/dogs/TCGA-BP-4176-01A-02R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4325-01A-02R-1289-07_output/dogs/TCGA-BP-4325-01A-02R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4326-01A-01R-1289-07_output/dogs/TCGA-BP-4326-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4335-01A-01R-1289-07_output/dogs/TCGA-BP-4335-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4343-01A-02R-1289-07_output/dogs/TCGA-BP-4343-01A-02R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4345-01A-01R-1289-07_output/dogs/TCGA-BP-4345-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4346-01A-01R-1289-07_output/dogs/TCGA-BP-4346-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4349-01A-01R-1289-07_output/dogs/TCGA-BP-4349-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4351-01A-01R-1289-07_output/dogs/TCGA-BP-4351-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4353-01A-02R-1289-07_output/dogs/TCGA-BP-4353-01A-02R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4354-01A-02R-1289-07_output/dogs/TCGA-BP-4354-01A-02R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4355-01A-01R-1289-07_output/dogs/TCGA-BP-4355-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4756-01A-01R-1289-07_output/dogs/TCGA-BP-4756-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4759-01A-01R-1289-07_output/dogs/TCGA-BP-4759-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4760-01A-02R-1420-07_output/dogs/TCGA-BP-4760-01A-02R-1420-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4761-01A-01R-1289-07_output/dogs/TCGA-BP-4761-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4762-01A-02R-1289-07_output/dogs/TCGA-BP-4762-01A-02R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4763-01A-01R-1289-07_output/dogs/TCGA-BP-4763-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4769-01A-01R-1289-07_output/dogs/TCGA-BP-4769-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4774-01A-01R-1289-07_output/dogs/TCGA-BP-4774-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4775-01A-01R-1289-07_output/dogs/TCGA-BP-4775-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4776-01A-01R-1289-07_output/dogs/TCGA-BP-4776-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4777-01A-01R-1289-07_output/dogs/TCGA-BP-4777-01A-01R-1289-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4781-01A-01R-1305-07_output/dogs/TCGA-BP-4781-01A-01R-1305-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4782-01A-02R-1420-07_output/dogs/TCGA-BP-4782-01A-02R-1420-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4784-01A-01R-1305-07_output/dogs/TCGA-BP-4784-01A-01R-1305-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4787-01A-01R-1305-07_output/dogs/TCGA-BP-4787-01A-01R-1305-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4790-01A-01R-1305-07_output/dogs/TCGA-BP-4790-01A-01R-1305-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4795-01A-02R-1420-07_output/dogs/TCGA-BP-4795-01A-02R-1420-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4799-01A-01R-1305-07_output/dogs/TCGA-BP-4799-01A-01R-1305-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4801-01A-02R-1420-07_output/dogs/TCGA-BP-4801-01A-02R-1420-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4803-01A-01R-1305-07_output/dogs/TCGA-BP-4803-01A-01R-1305-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-4993-01A-02R-1420-07_output/dogs/TCGA-BP-4993-01A-02R-1420-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-5010-01A-02R-1420-07_output/dogs/TCGA-BP-5010-01A-02R-1420-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-5170-01A-01R-1426-07_output/dogs/TCGA-BP-5170-01A-01R-1426-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-5173-01A-01R-1426-07_output/dogs/TCGA-BP-5173-01A-01R-1426-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-5174-01A-01R-1426-07_output/dogs/TCGA-BP-5174-01A-01R-1426-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-5177-01A-01R-1426-07_output/dogs/TCGA-BP-5177-01A-01R-1426-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-5183-01A-01R-1426-07_output/dogs/TCGA-BP-5183-01A-01R-1426-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-5184-01A-01R-1426-07_output/dogs/TCGA-BP-5184-01A-01R-1426-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-5185-01A-01R-1426-07_output/dogs/TCGA-BP-5185-01A-01R-1426-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-5186-01A-01R-1426-07_output/dogs/TCGA-BP-5186-01A-01R-1426-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-5187-01A-01R-1426-07_output/dogs/TCGA-BP-5187-01A-01R-1426-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-BP-5196-01A-01R-1426-07_output/dogs/TCGA-BP-5196-01A-01R-1426-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CW-5581-11A-01R-1541-07_output/dogs/TCGA-CW-5581-11A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CW-5584-11A-01R-1541-07_output/dogs/TCGA-CW-5584-11A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CW-5589-11A-01R-1541-07_output/dogs/TCGA-CW-5589-11A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CW-5591-01A-01R-1541-07_output/dogs/TCGA-CW-5591-01A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CW-5591-11A-01R-1541-07_output/dogs/TCGA-CW-5591-11A-01R-1541-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CW-6097-01A-11R-1672-07_output/dogs/TCGA-CW-6097-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-4857-01A-01R-1305-07_output/dogs/TCGA-CZ-4857-01A-01R-1305-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-4858-01A-01R-1305-07_output/dogs/TCGA-CZ-4858-01A-01R-1305-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-4860-01A-01R-1305-07_output/dogs/TCGA-CZ-4860-01A-01R-1305-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-4861-01A-01R-1305-07_output/dogs/TCGA-CZ-4861-01A-01R-1305-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-4862-01A-01R-1305-07_output/dogs/TCGA-CZ-4862-01A-01R-1305-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-4863-01A-01R-1503-07_output/dogs/TCGA-CZ-4863-01A-01R-1503-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-4865-11A-01R-1503-07_output/dogs/TCGA-CZ-4865-11A-01R-1503-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-5451-01A-01R-1503-07_output/dogs/TCGA-CZ-5451-01A-01R-1503-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-5452-01A-01R-1503-07_output/dogs/TCGA-CZ-5452-01A-01R-1503-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-5452-11A-01R-1503-07_output/dogs/TCGA-CZ-5452-11A-01R-1503-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-5456-11A-02R-1503-07_output/dogs/TCGA-CZ-5456-11A-02R-1503-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-5458-01A-01R-1503-07_output/dogs/TCGA-CZ-5458-01A-01R-1503-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-5459-01A-01R-1503-07_output/dogs/TCGA-CZ-5459-01A-01R-1503-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-5466-01A-01R-1503-07_output/dogs/TCGA-CZ-5466-01A-01R-1503-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-5467-01A-01R-1503-07_output/dogs/TCGA-CZ-5467-01A-01R-1503-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-5468-01A-01R-1503-07_output/dogs/TCGA-CZ-5468-01A-01R-1503-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-5468-11A-01R-1503-07_output/dogs/TCGA-CZ-5468-11A-01R-1503-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-5469-01A-01R-1503-07_output/dogs/TCGA-CZ-5469-01A-01R-1503-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-5982-01A-11R-1672-07_output/dogs/TCGA-CZ-5982-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-5986-01A-11R-1672-07_output/dogs/TCGA-CZ-5986-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-5987-11A-01R-1672-07_output/dogs/TCGA-CZ-5987-11A-01R-1672-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-5988-11A-01R-1672-07_output/dogs/TCGA-CZ-5988-11A-01R-1672-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-5989-01A-11R-1672-07_output/dogs/TCGA-CZ-5989-01A-11R-1672-07.dogs.bed
# /private/projects/kidney_rtt/dogs/only_dogs/TCGA-CZ-5989-11A-01R-1672-07_output/dogs/TCGA-CZ-5989-11A-01R-1672-07.dogs.bed
# count  110

# %%
# apply the intersect with dogs and count_lines_with_zero_last_column on all the bed file from the output of arriba

# Specify the directory path
directory_arriba = '/private/projects/kidney_rtt/filters_arriba_bed'
directory_artdeco = "/private/projects/kidney_rtt/dogs_all_samples"
samples_not_found_in_arriba = []
# Loop over files in the directory
for filename in os.listdir(directory_artdeco):
    if filename.endswith(".bed"):  
        file_path_artdeco = os.path.join(directory_artdeco, filename)
        artdeco_bed = file_path_artdeco
        split_list = filename.split("-")
        number_sample = split_list[2]
        print("number sample : ", number_sample)
        
        arriba_bed_files = find_files_with_number(directory_arriba, number_sample)
        print(arriba_bed_files)
        if(len(arriba_bed_files)==0):
            samples_not_found_in_arriba.append(number_sample)
            continue
        arriba_bed = arriba_bed_files[0]

        new_filename = f"intersect_{filename}"
        output_path = os.path.join("/private/projects/kidney_rtt/intersect_all_samples", new_filename)

        run_bedtools_intersect(artdeco_bed, arriba_bed, output_path)
        zero_count, zero_percentage = count_lines_with_zero_last_column(output_path)

        summary_path = "/private/projects/kidney_rtt/intersect_all_samples/summary_intersect.txt"
        with open(summary_path, 'a') as sammary:
            sammary.write("sample: "+str(number_sample)+"\n")
            sammary.write("Number of lines with 0 in the last column:\t" + str(zero_count) + "\n")
            sammary.write("Percentage of lines with 0 in the last column:\t{:.2f}%\n".format(zero_percentage))
            sammary.write("Percentage of lines without 0 in the last column:\t{:.2f}%\n\n".format(100 - zero_percentage))
print("samples not found in arriba: ", samples_not_found_in_arriba)
